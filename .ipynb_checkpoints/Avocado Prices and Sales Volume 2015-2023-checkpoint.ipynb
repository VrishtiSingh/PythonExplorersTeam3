# %% [markdown]
# # Avocado Prices and Sales Volume 2015-2023

# %%
from IPython.display import Image
Image(url='https://www.buygrow.co.za/cdn/shop/products/FuerteAvocadoWB.png?v=1675280423')
# Out:
# <img src="https://www.buygrow.co.za/cdn/shop/products/FuerteAvocadoWB.png?v=1675280423"/>

# %% [markdown]
# # Table of Contents
# - [1. Project Overview](#1-project-overview)
#   - [1.1 Introduction](#11-introduction)
#   - [1.2 Problem Statement](#12-problem-statement)
#   - [1.3 Objectives](#13-objectives)
# - [2. Importing Packages](#2-importing-packages)
# - [3. Loading Data](#3-loading-data)
# - [4. Data Cleaning](#4-data-cleaning)
# - [5. Exploratory Data Analysis (EDA)](#5-exploratory-data-analysis-eda)
# - [6. Conclusion](#6-conclusion)

# %% [markdown]
# ### 1. Project Overview

# %% [markdown]
# ##### 1.1 Introduction

# %% [markdown]
# ##### 1.2 Problem Statement

# %% [markdown]
# ##### 1.3 Objectives

# %% [markdown]
# ### 2. Importing Packages

# %%
# Libraries for data loading, manipulation and analysis

import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# Displays output inline
# %matplotlib inline

# Libraries for Handing Errors
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 3. Loading Data

# %% [markdown]
# The data used for this project was located in the Avocado_HassAvocadoBoard_20152023v1.0.1.csv file. To better manipulate and analyse the Avocado_HassAvocadoBoard_20152023v1.0.1.csv file, it was loaded into a Pandas Data Frame using the Pandas function, .read_csv().

# %%
# loading dataset
df = pd.read_csv("Avocado_HassAvocadoBoard_20152023v1.0.1.csv", index_col=False)

# %% [markdown]
# Check the DataFrame to see if it loaded correctly.

# %%
df.head()
# Out:
#          Date  AveragePrice  TotalVolume    plu4046    plu4225   plu4770  \
# 0  2015-01-04          1.22     40873.28    2819.50   28287.42     49.90
# 1  2015-01-04          1.79      1373.95      57.42     153.88      0.00
# 2  2015-01-04          1.00    435021.49  364302.39   23821.16     82.15
# 3  2015-01-04          1.76      3846.69    1500.15     938.35      0.00
# 4  2015-01-04          1.08    788025.06   53987.31  552906.04  39995.03
#
#    TotalBags  SmallBags  LargeBags  XLargeBags          type  \
# 0    9716.46    9186.93     529.53         0.0  conventional
# 1    1162.65    1162.65       0.00         0.0       organic
# 2   46815.79   16707.15   30108.64         0.0  conventional
# 3    1408.19    1071.35     336.84         0.0       organic
# 4  141136.68  137146.07    3990.61         0.0  conventional
#
#                 region
# 0               Albany
# 1               Albany
# 2              Atlanta
# 3              Atlanta
# 4  BaltimoreWashington

# %%
# Displays the number of rows and columns
df.shape
# Out:
# (53415, 12)

# %% [markdown]
# Results : The dataset consists of 53415 rows (observations) and 12 columns (features).

# %%
## Display summary information about the DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53415 entries, 0 to 53414
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          53415 non-null  object
#  1   AveragePrice  53415 non-null  float64
#  2   TotalVolume   53415 non-null  float64
#  3   plu4046       53415 non-null  float64
#  4   plu4225       53415 non-null  float64
#  5   plu4770       53415 non-null  float64
#  6   TotalBags     53415 non-null  float64
#  7   SmallBags     41025 non-null  float64
#  8   LargeBags     41025 non-null  float64
#  9   XLargeBags    41025 non-null  float64
#  10  type          53415 non-null  object
#  11  region        53415 non-null  object
# dtypes: float64(9), object(3)
# memory usage: 4.9+ MB

# %%
df.describe()
# Out:
#        AveragePrice   TotalVolume       plu4046       plu4225       plu4770  \
# count  53415.000000  5.341500e+04  5.341500e+04  5.341500e+04  5.341500e+04
# mean       1.428910  8.694474e+05  2.982707e+05  2.222170e+05  2.053195e+04
# std        0.393116  3.545274e+06  1.307669e+06  9.554624e+05  1.040977e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.119091  1.626465e+04  6.947250e+02  2.120800e+03  0.000000e+00
# 50%        1.400000  1.203525e+05  1.458058e+04  1.751663e+04  9.005000e+01
# 75%        1.690000  4.542380e+05  1.287924e+05  9.351560e+04  3.599735e+03
# max        3.440830  6.103446e+07  2.544720e+07  2.047057e+07  2.860025e+06
#
#           TotalBags     SmallBags     LargeBags     XLargeBags
# count  5.341500e+04  4.102500e+04  4.102500e+04   41025.000000
# mean   2.175083e+05  1.039222e+05  2.331316e+04    2731.811796
# std    8.676947e+05  5.692608e+05  1.496622e+05   22589.096454
# ...

# %% [markdown]
# ### 4. Data Cleaning

# %%
# Creating a copy of the dataframe where the cleaning will be made
df_copy = df
df_copy
# Out:
#              Date  AveragePrice  TotalVolume    plu4046    plu4225   plu4770  \
# 0      2015-01-04      1.220000     40873.28    2819.50   28287.42     49.90
# 1      2015-01-04      1.790000      1373.95      57.42     153.88      0.00
# 2      2015-01-04      1.000000    435021.49  364302.39   23821.16     82.15
# 3      2015-01-04      1.760000      3846.69    1500.15     938.35      0.00
# 4      2015-01-04      1.080000    788025.06   53987.31  552906.04  39995.03
# ...           ...           ...          ...        ...        ...       ...
# 53410  2023-12-03      1.550513      5693.91     204.64    1211.25      0.00
# 53411  2023-12-03      1.703920    343326.10   66808.44  132075.11     58.65
# 53412  2023-12-03      1.618931     34834.86   15182.42    1211.38      0.00
# 53413  2023-12-03      1.245406      2942.83    1058.54       7.46      0.00
# 53414  2023-12-03      1.479240   2010020.72  271808.32  274480.64     63.43
#
# ...

# %%
# Retrieving columns containing null values
# Only 3 columns contain null values, all of which are of float data type
df_copy.isnull().any()
# Out:
# Date            False
# AveragePrice    False
# TotalVolume     False
# plu4046         False
# plu4225         False
# plu4770         False
# TotalBags       False
# SmallBags        True
# LargeBags        True
# XLargeBags       True
# type            False
# region          False
# dtype: bool

# %%
# Replacing the NaN values with their respective column means

df_copy['SmallBags'] = df_copy['SmallBags'].astype(str)
df_copy['SmallBags'].replace('NaN', None)
df_copy['SmallBags'] = df_copy['SmallBags'].astype(float)
df_copy['SmallBags'].fillna(df_copy['SmallBags'].mean(), inplace=True)

df_copy['LargeBags'] = df_copy['LargeBags'].astype(str)
df_copy['LargeBags'].replace('NaN', None)
df_copy['LargeBags'] = df_copy['LargeBags'].astype(float)
df_copy['LargeBags'].fillna(df_copy['LargeBags'].mean(), inplace=True)

df_copy['XLargeBags'] = df_copy['XLargeBags'].astype(str)
df_copy['XLargeBags'].replace('NaN', None)
df_copy['XLargeBags'] = df_copy['XLargeBags'].astype(float)
df_copy['XLargeBags'].fillna(df_copy['XLargeBags'].mean(), inplace=True)

df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53415 entries, 0 to 53414
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          53415 non-null  object
#  1   AveragePrice  53415 non-null  float64
#  2   TotalVolume   53415 non-null  float64
#  3   plu4046       53415 non-null  float64
#  4   plu4225       53415 non-null  float64
#  5   plu4770       53415 non-null  float64
#  6   TotalBags     53415 non-null  float64
#  7   SmallBags     53415 non-null  float64
#  8   LargeBags     53415 non-null  float64
#  9   XLargeBags    53415 non-null  float64
#  10  type          53415 non-null  object
#  11  region        53415 non-null  object
# dtypes: float64(9), object(3)
# memory usage: 4.9+ MB

# %%
# Adding a 'Year' column which holds the year value from the 'Date' column
df_copy['Year'] = df_copy['Date'].str.slice(0, 4).astype(int)

# Adding a 'Month' column which holds the month value from the 'Date' column
df_copy['Month'] = df_copy['Date'].str.slice(5, 7).astype(int)

df_copy
# Out:
#              Date  AveragePrice  TotalVolume    plu4046    plu4225   plu4770  \
# 0      2015-01-04      1.220000     40873.28    2819.50   28287.42     49.90
# 1      2015-01-04      1.790000      1373.95      57.42     153.88      0.00
# 2      2015-01-04      1.000000    435021.49  364302.39   23821.16     82.15
# 3      2015-01-04      1.760000      3846.69    1500.15     938.35      0.00
# 4      2015-01-04      1.080000    788025.06   53987.31  552906.04  39995.03
# ...           ...           ...          ...        ...        ...       ...
# 53410  2023-12-03      1.550513      5693.91     204.64    1211.25      0.00
# 53411  2023-12-03      1.703920    343326.10   66808.44  132075.11     58.65
# 53412  2023-12-03      1.618931     34834.86   15182.42    1211.38      0.00
# 53413  2023-12-03      1.245406      2942.83    1058.54       7.46      0.00
# 53414  2023-12-03      1.479240   2010020.72  271808.32  274480.64     63.43
#
# ...

# %%
# Run this to set the changes made on 'df_copy' to the main dataframe 'df'
df = df_copy
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53415 entries, 0 to 53414
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          53415 non-null  object
#  1   AveragePrice  53415 non-null  float64
#  2   TotalVolume   53415 non-null  float64
#  3   plu4046       53415 non-null  float64
#  4   plu4225       53415 non-null  float64
#  5   plu4770       53415 non-null  float64
#  6   TotalBags     53415 non-null  float64
#  7   SmallBags     53415 non-null  float64
#  8   LargeBags     53415 non-null  float64
#  9   XLargeBags    53415 non-null  float64
#  10  type          53415 non-null  object
#  11  region        53415 non-null  object
#  12  Year          53415 non-null  int64
#  13  Month         53415 non-null  int64
# dtypes: float64(9), int64(2), object(3)
# memory usage: 5.7+ MB

# %% [markdown]
# ### 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# <h4>Distribution of average prices filterded by region</h4>

# %%
# filtering regions, to show only regions
regions_of_interest = ['California', 'Plains', 'South Central', 'Southeast', 'Midsouth', 'Great Lakes', 'Northeast']

# filter the DataFrame by regions
filtered_df = df[df['region'].isin(regions_of_interest)]
filtered_df.head(2)
# Out:
#           Date  AveragePrice  TotalVolume     plu4046     plu4225    plu4770  \
# 12  2015-01-04          0.93   5777334.90  2843648.26  2267755.26  137479.64
# 13  2015-01-04          1.24    142349.77   107490.73    25711.96       2.93
#
#     TotalBags  SmallBags  LargeBags  XLargeBags          type      region  \
# 12  528451.74  477193.38   47882.56      3375.8  conventional  California
# 13    9144.15    9144.15       0.00         0.0       organic  California
#
#     Year  Month
# 12  2015      1
# 13  2015      1

# %%
filtered_df['AveragePrice'].hist(bins=20)
plt.title('Distribution of Average Price')
plt.xlabel('Average Price')
plt.ylabel('Frequency')
plt.show()

filtered_df['TotalVolume'].hist(bins=20)
plt.title('Distribution of Total Volume')
plt.xlabel('Total Volume')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x='region', y='AveragePrice', data = filtered_df)
plt.xticks(rotation=90)
plt.title('Average Price by Region')
plt.show()


sns.boxplot(x='region', y='AveragePrice', data = filtered_df)
plt.xticks(rotation=90)
plt.title('Average Price by Region')
plt.show()

# %%
round(filtered_df.describe().T,3)
# Out:
#                count         mean          std       min         25%  \
# AveragePrice  4660.0        1.438        0.325      0.62       1.166
# TotalVolume   4660.0  2102344.307  2233972.647  21986.87  169944.387
# plu4046       4660.0   690085.381   928140.631      0.00    8950.825
# plu4225       4660.0   602802.403   907266.926      0.00   21384.755
# plu4770       4660.0    37745.941   106505.408      0.00      45.293
# TotalBags     4660.0   553294.713   550535.922   4836.22   88649.848
# SmallBags     4660.0   225134.891   398893.028      0.00       0.000
# LargeBags     4660.0    35411.309    90551.764      0.00       0.000
# XLargeBags    4660.0     5111.649    14518.383      0.00       0.000
# Year          4660.0     2018.970        2.569   2015.00    2017.000
# Month         4660.0        6.468        3.432      1.00       4.000
#
#                      50%          75%          max
# AveragePrice       1.414        1.684         2.58
# ...

# %% [markdown]
# ### 6. Conclusion
