# %% [markdown]
# # Avocado Prices and Sales Volume 2015-2023

# %%
from IPython.display import Image
Image(url='https://www.buygrow.co.za/cdn/shop/products/FuerteAvocadoWB.png?v=1675280423')
# Out:
# <img src="https://www.buygrow.co.za/cdn/shop/products/FuerteAvocadoWB.png?v=1675280423"/>

# %% [markdown]
# # Table of Contents
# - [1. Project Overview](#1-project-overview)
#   - [1.1 Introduction](#11-introduction)
#   - [1.2 Problem Statement](#12-problem-statement)
#   - [1.3 Objectives](#13-objectives)
# - [2. Importing Packages](#2-importing-packages)
# - [3. Loading Data](#3-loading-data)
# - [4. Data Cleaning](#4-data-cleaning)
# - [5. Exploratory Data Analysis (EDA)](#5-exploratory-data-analysis-eda)
# - [6. Conclusion](#6-conclusion)

# %% [markdown]
# ### 1. Project Overview

# %% [markdown]
# ##### 1.1 Introduction

# %% [markdown]
# This project focuses on data cleaning and exploratory data analysis (EDA) of historical avocado prices. The primary goal is to clean the dataset and explore trends, seasonal patterns, and potential factors affecting avocado prices, setting a foundation for future predictive modeling.

# %% [markdown]
# ##### 1.2 Problem Statement

# %% [markdown]
# The aim is to prepare and explore a dataset of historical avocado prices to gain insights into pricing trends and potential factors affecting prices. This analysis will provide a deeper understanding of data patterns, enabling stakeholders to make preliminary observations and setting the foundation for future predictive modeling.

# %% [markdown]
# ##### 1.3 Objectives

# %% [markdown]
# <ul>
#     <li>Data Cleaning: Ensure data quality by handling missing values, correcting data types and adding new columns.</li>
# <li>
# Exploratory Data Analysis (EDA): Identify trends, seasonal variations, and key differences in avocado prices by region and type (conventional vs. organic
# </li>
# </ul>.

# %% [markdown]
# ### 2. Importing Packages

# %% [markdown]
# To carry out data cleaning, manipulation, and visualization, we’ll use the following Python libraries:
# <ul>
# <li>pandas: Provides data structures and functions needed to efficiently clean and manipulate the dataset.</li>
# <li>numpy: Adds support for numerical operations, including handling arrays and mathematical functions for outlier treatment.</li>
# <li>matplotlib and seaborn: Libraries for data visualization. matplotlib is a core plotting library, while seaborn builds on it to provide more aesthetic and statistical visualizations.</li>
# </ul>

# %%
# Libraries for data loading, manipulation and analysis

import numpy as np
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# Displays output inline
# %matplotlib inline

# Libraries for Handing Errors
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 3. Loading Data

# %% [markdown]
# The data used for this project was located in the Avocado_HassAvocadoBoard_20152023v1.0.1.csv file. To better manipulate and analyse the Avocado_HassAvocadoBoard_20152023v1.0.1.csv file, it was loaded into a Pandas Data Frame using the Pandas function, .read_csv().

# %%
# loading dataset
df = pd.read_csv("Avocado_HassAvocadoBoard_20152023v1.0.1.csv", index_col=False)

# %% [markdown]
# Check the DataFrame to see if it loaded correctly.

# %%
df.head()
# Out:
#          Date  AveragePrice  TotalVolume    plu4046    plu4225   plu4770  \
# 0  2015-01-04          1.22     40873.28    2819.50   28287.42     49.90
# 1  2015-01-04          1.79      1373.95      57.42     153.88      0.00
# 2  2015-01-04          1.00    435021.49  364302.39   23821.16     82.15
# 3  2015-01-04          1.76      3846.69    1500.15     938.35      0.00
# 4  2015-01-04          1.08    788025.06   53987.31  552906.04  39995.03
#
#    TotalBags  SmallBags  LargeBags  XLargeBags          type  \
# 0    9716.46    9186.93     529.53         0.0  conventional
# 1    1162.65    1162.65       0.00         0.0       organic
# 2   46815.79   16707.15   30108.64         0.0  conventional
# 3    1408.19    1071.35     336.84         0.0       organic
# 4  141136.68  137146.07    3990.61         0.0  conventional
#
#                 region
# 0               Albany
# 1               Albany
# 2              Atlanta
# 3              Atlanta
# 4  BaltimoreWashington

# %%
# Displays the number of rows and columns
df.shape
# Out:
# (53415, 12)

# %% [markdown]
# Results : The dataset consists of 53415 rows (observations) and 12 columns (features).

# %%
## Display summary information about the DataFrame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53415 entries, 0 to 53414
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          53415 non-null  object
#  1   AveragePrice  53415 non-null  float64
#  2   TotalVolume   53415 non-null  float64
#  3   plu4046       53415 non-null  float64
#  4   plu4225       53415 non-null  float64
#  5   plu4770       53415 non-null  float64
#  6   TotalBags     53415 non-null  float64
#  7   SmallBags     41025 non-null  float64
#  8   LargeBags     41025 non-null  float64
#  9   XLargeBags    41025 non-null  float64
#  10  type          53415 non-null  object
#  11  region        53415 non-null  object
# dtypes: float64(9), object(3)
# memory usage: 4.9+ MB

# %%
df.describe()
# Out:
#        AveragePrice   TotalVolume       plu4046       plu4225       plu4770  \
# count  53415.000000  5.341500e+04  5.341500e+04  5.341500e+04  5.341500e+04
# mean       1.428910  8.694474e+05  2.982707e+05  2.222170e+05  2.053195e+04
# std        0.393116  3.545274e+06  1.307669e+06  9.554624e+05  1.040977e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.119091  1.626465e+04  6.947250e+02  2.120800e+03  0.000000e+00
# 50%        1.400000  1.203525e+05  1.458058e+04  1.751663e+04  9.005000e+01
# 75%        1.690000  4.542380e+05  1.287924e+05  9.351560e+04  3.599735e+03
# max        3.440830  6.103446e+07  2.544720e+07  2.047057e+07  2.860025e+06
#
#           TotalBags     SmallBags     LargeBags     XLargeBags
# count  5.341500e+04  4.102500e+04  4.102500e+04   41025.000000
# mean   2.175083e+05  1.039222e+05  2.331316e+04    2731.811796
# std    8.676947e+05  5.692608e+05  1.496622e+05   22589.096454
# ...

# %% [markdown]
# ### 4. Data Cleaning

# %% [markdown]
# We start by making a copy of our dataframe so that we do not lose our data in case we make mistakes

# %%
# Creating a copy of the dataframe where the cleaning will be made
df_copy = df
df_copy
# Out:
#              Date  AveragePrice  TotalVolume    plu4046    plu4225   plu4770  \
# 0      2015-01-04      1.220000     40873.28    2819.50   28287.42     49.90
# 1      2015-01-04      1.790000      1373.95      57.42     153.88      0.00
# 2      2015-01-04      1.000000    435021.49  364302.39   23821.16     82.15
# 3      2015-01-04      1.760000      3846.69    1500.15     938.35      0.00
# 4      2015-01-04      1.080000    788025.06   53987.31  552906.04  39995.03
# ...           ...           ...          ...        ...        ...       ...
# 53410  2023-12-03      1.550513      5693.91     204.64    1211.25      0.00
# 53411  2023-12-03      1.703920    343326.10   66808.44  132075.11     58.65
# 53412  2023-12-03      1.618931     34834.86   15182.42    1211.38      0.00
# 53413  2023-12-03      1.245406      2942.83    1058.54       7.46      0.00
# 53414  2023-12-03      1.479240   2010020.72  271808.32  274480.64     63.43
#
# ...

# %% [markdown]
# In the region column, we have regions combined with sub-regions and the total data for the US. We take a closer look by viewing the unique values contained in the region column.

# %%
# The region column is actually locations mixed with regions and total US data

unique_region_values = df_copy.region.drop_duplicates()
unique_region_values
# Out:
# 0                      Albany
# 2                     Atlanta
# 4         BaltimoreWashington
# 6                       Boise
# 8                      Boston
# 10           BuffaloRochester
# 12                 California
# 14                  Charlotte
# 16                    Chicago
# 18           CincinnatiDayton
# 20                   Columbus
# 22              DallasFtWorth
# 24                     Denver
# 26                    Detroit
# 28                GrandRapids
# 30                 GreatLakes
# 32         HarrisburgScranton
# 34        HartfordSpringfield
# 36                    Houston
# 38               Indianapolis
# 40               Jacksonville
# 42                   LasVegas
# 44                 LosAngeles
# 46                 Louisville
# 48                      Miami
# 50                   Midsouth
# 52                  Nashville
# 54                 NewOrleans
# 56                    NewYork
# 58                  Northeast
# 60         NorthernNewEngland
# ...

# %% [markdown]
# In accordance to the data dictionary for avocado sales in the US, found in this link: https://cran.r-project.org/web/packages/avocado/vignettes/a_intro.html, there are 8 regions, namely:
#
# 1. California
# 2. West
# 3. Plains
# 4. SouthCentral
# 5. Southeast
# 6. Midsouth
# 7. GreatLakes
# 8. Northeast
#
# We now separate the dataset into three dataframes for regions, sub-regions or individual locations, and for the US total.

# %%
# Seperating regions from the dataset
region_names = ['California', 'West', 'Plains', 'SouthCentral',
                'Southeast', 'Midsouth', 'GreatLakes', 'Northeast']

regions_df = df_copy.query('region in @region_names')

regions_df
# Out:
#              Date  AveragePrice  TotalVolume     plu4046     plu4225  \
# 12     2015-01-04      0.930000   5777334.90  2843648.26  2267755.26
# 13     2015-01-04      1.240000    142349.77   107490.73    25711.96
# 30     2015-01-04      1.020000   3382800.12   467259.47  2059657.71
# 31     2015-01-04      1.540000     61615.10     3633.93    42963.06
# 50     2015-01-04      1.100000   2578275.12   575245.44  1311502.53
# ...           ...           ...          ...         ...         ...
# 53387  2023-12-03      1.404208    314344.43    16056.66    21969.60
# 53393  2023-12-03      1.309767     59865.39     9819.27     2863.94
# 53404  2023-12-03      1.261000    172951.53    43352.71     3886.13
# 53405  2023-12-03      1.263368    348740.78     2465.90    17244.86
# 53411  2023-12-03      1.703920    343326.10    66808.44   132075.11
#
#          plu4770  TotalBags  SmallBags  LargeBags  XLargeBags          type  \
# ...

# %%
# Seperating the locations and totalUS from the dataset
us_total = 'TotalUS'
total_us_df = df_copy.query('region == @us_total')
total_us_df = total_us_df.rename(columns={'region': 'Location'})

locations_df = df_copy.query('region not in @region_names')
locations_df = locations_df.query('region != @us_total')
locations_df = locations_df.rename(columns={'region': 'Location'})

# %% [markdown]
# Now we have three dataframes
#
# 1. regions_df for regions only
# 2. locations_df for individual locations or sub-regions only
# 3. total_us_df for all of US
#
# We start looking for presence of null values in our data for all three dataframes

# %%
# Checking for data with null values regions_df
regions_df.isnull().any()
# Out:
# Date            False
# AveragePrice    False
# TotalVolume     False
# plu4046         False
# plu4225         False
# plu4770         False
# TotalBags       False
# SmallBags        True
# LargeBags        True
# XLargeBags       True
# type            False
# region          False
# dtype: bool

# %%
# Checking for data with null values for locations_df
locations_df.isnull().any()
# Out:
# Date            False
# AveragePrice    False
# TotalVolume     False
# plu4046         False
# plu4225         False
# plu4770         False
# TotalBags       False
# SmallBags        True
# LargeBags        True
# XLargeBags       True
# type            False
# Location        False
# dtype: bool

# %%
# Checking for data with null values for total_us_df
total_us_df.isnull().any()
# Out:
# Date            False
# AveragePrice    False
# TotalVolume     False
# plu4046         False
# plu4225         False
# plu4770         False
# TotalBags       False
# SmallBags        True
# LargeBags        True
# XLargeBags       True
# type            False
# Location        False
# dtype: bool

# %% [markdown]
# Null values are present in 3 columns of all our dataframes, `'SmallBags'`, `'LargeBags'`, and `'XLargeBags'`. We amputate the data by replacing these null values with their respective column means.

# %%
# This is for replacing null values for the regions_df
regions_df['SmallBags'] = regions_df['SmallBags'].astype(str)
regions_df['SmallBags'].replace('NaN', None)
regions_df['SmallBags'] = regions_df['SmallBags'].astype(float)
regions_df['SmallBags'].fillna(regions_df['SmallBags'].mean(), inplace=True)

regions_df['LargeBags'] = regions_df['LargeBags'].astype(str)
regions_df['LargeBags'].replace('NaN', None)
regions_df['LargeBags'] = regions_df['LargeBags'].astype(float)
regions_df['LargeBags'].fillna(regions_df['LargeBags'].mean(), inplace=True)

regions_df['XLargeBags'] = regions_df['XLargeBags'].astype(str)
regions_df['XLargeBags'].replace('NaN', None)
regions_df['XLargeBags'] = regions_df['XLargeBags'].astype(float)
regions_df['XLargeBags'].fillna(regions_df['XLargeBags'].mean(), inplace=True)

regions_df.isnull().any()
# Out:
# Date            False
# AveragePrice    False
# TotalVolume     False
# plu4046         False
# plu4225         False
# plu4770         False
# TotalBags       False
# SmallBags       False
# LargeBags       False
# XLargeBags      False
# type            False
# region          False
# dtype: bool

# %%
# This is for replacing null values for the locations_df
locations_df['SmallBags'] = locations_df['SmallBags'].astype(str)
locations_df['SmallBags'].replace('NaN', None)
locations_df['SmallBags'] = locations_df['SmallBags'].astype(float)
locations_df['SmallBags'].fillna(locations_df['SmallBags'].mean(), inplace=True)

locations_df['LargeBags'] = locations_df['LargeBags'].astype(str)
locations_df['LargeBags'].replace('NaN', None)
locations_df['LargeBags'] = locations_df['LargeBags'].astype(float)
locations_df['LargeBags'].fillna(locations_df['LargeBags'].mean(), inplace=True)

locations_df['XLargeBags'] = locations_df['XLargeBags'].astype(str)
locations_df['XLargeBags'].replace('NaN', None)
locations_df['XLargeBags'] = locations_df['XLargeBags'].astype(float)
locations_df['XLargeBags'].fillna(locations_df['XLargeBags'].mean(), inplace=True)

locations_df.isnull().any()
# Out:
# Date            False
# AveragePrice    False
# TotalVolume     False
# plu4046         False
# plu4225         False
# plu4770         False
# TotalBags       False
# SmallBags       False
# LargeBags       False
# XLargeBags      False
# type            False
# Location        False
# dtype: bool

# %%
# This is for replacing null values for the total_us_df
total_us_df['SmallBags'] = total_us_df['SmallBags'].astype(str)
total_us_df['SmallBags'].replace('NaN', None)
total_us_df['SmallBags'] = total_us_df['SmallBags'].astype(float)
total_us_df['SmallBags'].fillna(total_us_df['SmallBags'].mean(), inplace=True)

total_us_df['LargeBags'] = total_us_df['LargeBags'].astype(str)
total_us_df['LargeBags'].replace('NaN', None)
total_us_df['LargeBags'] = total_us_df['LargeBags'].astype(float)
total_us_df['LargeBags'].fillna(total_us_df['LargeBags'].mean(), inplace=True)

total_us_df['XLargeBags'] = total_us_df['XLargeBags'].astype(str)
total_us_df['XLargeBags'].replace('NaN', None)
total_us_df['XLargeBags'] = total_us_df['XLargeBags'].astype(float)
total_us_df['XLargeBags'].fillna(total_us_df['XLargeBags'].mean(), inplace=True)

total_us_df.isnull().any()
# Out:
# Date            False
# AveragePrice    False
# TotalVolume     False
# plu4046         False
# plu4225         False
# plu4770         False
# TotalBags       False
# SmallBags       False
# LargeBags       False
# XLargeBags      False
# type            False
# Location        False
# dtype: bool

# %% [markdown]
# Now that we no longer have any null values in our data, we move on to adding two columns in our dataframes, `'Year'` and `'Month'`. These columns hold the year part and the month part from the `'Date'` column respectively.

# %%
# Adding 'Year' and 'Month' columns for regions_df
regions_df['Year'] = regions_df['Date'].str.slice(0, 4).astype(int)
regions_df['Month'] = regions_df['Date'].str.slice(5, 7).astype(int)

# Adding 'Year' and 'Month' columns for locations_df
locations_df['Year'] = locations_df['Date'].str.slice(0, 4).astype(int)
locations_df['Month'] = locations_df['Date'].str.slice(5, 7).astype(int)

# Adding 'Year' and 'Month' columns for total_us_df
total_us_df['Year'] = total_us_df['Date'].str.slice(0, 4).astype(int)
total_us_df['Month'] = total_us_df['Date'].str.slice(5, 7).astype(int)

# These are the 3 dataframes we have
regions_df.info()
locations_df.info()
total_us_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7456 entries, 12 to 53411
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          7456 non-null   object
#  1   AveragePrice  7456 non-null   float64
#  2   TotalVolume   7456 non-null   float64
#  3   plu4046       7456 non-null   float64
#  4   plu4225       7456 non-null   float64
#  5   plu4770       7456 non-null   float64
#  6   TotalBags     7456 non-null   float64
#  7   SmallBags     7456 non-null   float64
#  8   LargeBags     7456 non-null   float64
#  9   XLargeBags    7456 non-null   float64
#  10  type          7456 non-null   object
#  11  region        7456 non-null   object
#  12  Year          7456 non-null   int32
#  13  Month         7456 non-null   int32
# dtypes: float64(9), int32(2), object(3)
# memory usage: 815.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 45027 entries, 0 to 53413
# Data columns (total 14 columns):
# ...

# %% [markdown]
# Our data is now clean. The dataframes that will be used for EDA are `regions_df`, `locations_df`, and `total_us_df`.

# %% [markdown]
# ### 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# <h3> 5.1 Univariate Analysis</h3>

# %%
#Distribution of price

# Set up a figure with 2 subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Histogram of Average Price on ax1
sns.histplot(data=locations_df, x='AveragePrice', bins=30, kde=True, ax=ax1)
ax1.set_title('Distribution of Avocado Prices')
ax1.set_xlabel('Average Price')
ax1.set_ylabel('Frequency')

# Box plot of Average Price by Type on ax2
sns.boxplot(data=locations_df, x='type', y='AveragePrice', ax=ax2)
ax2.set_title('Average Avocado Prices by Type')
ax2.set_xlabel('Type')
ax2.set_ylabel('Average Price')

# Adjusting the spacing between plots
fig.subplots_adjust(wspace=0.3)

plt.show()

# %% [markdown]
# Looking at the first graph we see two peaks, which indicate that price clusteres around two separate prices. The leftmost peak is the mode price for conventional avocados, as is supported by the box plot. The other peak represents the mode price for the organic avocados. The higher peak also indicates that the conventional avocado's price is more clustered aorund that price versus the organic avocados.
# The distribution curves are also both slightly positively skewed.
#
# Looking at the box plots we can confirm just how clustered price is for both types, by the height of their boxes, which represent the middle 50% of the data.

# %%
# Average price and volume per month

# Create a figure with 2 subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Line plot of Average Price by Month on ax1
sns.lineplot(data=locations_df, x='Month', y='AveragePrice', ci=None, ax=ax1)
ax1.set_title('Avocado Prices Per Month')
ax1.set_xlabel('Month')
ax1.set_ylabel('Average Price')

# Line plot of Total Volume by Month on ax2
sns.lineplot(data=locations_df, x='Month', y='TotalVolume', ci=None, ax=ax2)
ax2.set_title('Average Volume of Avocados Sold Per Month')
ax2.set_xlabel('Month')
ax2.set_ylabel('Average Volume')

# Adjust horizontal spacing between plots
fig.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# Looking at the shape of both curves, we can clearly identify the presence of seasonality in the price change. Although price and volume seem inversely proportional, there is a clear case to be made that in summer (in the US), avocados are bought less, as seen by the decreasing volume. The increase in price over the same period may be due to supply and demand where as price increases, volume decreases.

# %%
# Average price and volume per year

# Create a figure with 2 subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Line plot of Average Price by Month on ax1
sns.lineplot(data=locations_df, x='Year', y='AveragePrice', ci=None, ax=ax1)
ax1.set_title('Avocado Prices Per Year')
ax1.set_xlabel('Year')
ax1.set_ylabel('Average Price')

# Line plot of Total Volume by Month on ax2
sns.lineplot(data=locations_df, x='Year', y='TotalVolume', ci=None, ax=ax2)
ax2.set_title('Average Volume of Avocados Sold Per Year')
ax2.set_xlabel('Year')
ax2.set_ylabel('Average Volume')

# Adjust horizontal spacing between plots
fig.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# - The fluctuations in avocado prices do not seem to correlate directly with the sales volume, as price peaks in certain years (like 2017 and 2020) do not directly result in volume drops.
# - Despite price volatility, the overall volume of avocados sold has increased, which could imply that consumer demand remains strong even when prices fluctuate.
# - The long-term upward trend in sales volume might suggest increasing popularity or accessibility of avocados, while prices may be influenced by other factors such as seasonal availability, supply chain variations, or external economic conditions.

# %%
# Average price and volume per year

# Create a figure with 2 subplots stacked vertically
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Bar plot of Average Price by Region on ax1
sns.barplot(data=regions_df, x='region', y='AveragePrice', ci=None, ax=ax1)
ax1.set_title('Avocado Prices Per Region')
ax1.set_xlabel('Region')
ax1.set_ylabel('Average Price')

# Bar plot of Total Volume by Region on ax2
sns.barplot(data=regions_df, x='region', y='TotalVolume', ci=None, ax=ax2)
ax2.set_title('Average Volume of Avocados Sold Per Region')
ax2.set_xlabel('Region')
ax2.set_ylabel('Average Volume')

# Adjust vertical spacing between plots
fig.subplots_adjust(hspace=0.5)

plt.show()

# %% [markdown]
# There doesn't seem to be a clear relationship between volume and price per region, as the regions have relatively similar prices, within about 50c of each other. The volume curve adds onto this point as the avocados sold greatly varies between the regions.

# %%
# Calculation of the total volume for each avocado type
volume_by_type = locations_df.groupby('type')['TotalVolume'].sum()

# Plotting the pie chart
plt.figure(figsize=(6, 6))
plt.pie(volume_by_type, labels=volume_by_type.index, autopct='%1.1f%%', startangle=90)

# Equal aspect ratio ensures the pie chart is a circle.
plt.axis('equal')
plt.title("Avocado Market Total Volume Sold by Type")
plt.show()

# %% [markdown]
# This pie chart shows that conventional avocados have dominated the market versus organic, and may be a reason for individuals or enterprises to potentially consider the type of avocados being sold. This coupled with the fact that conventional avocados are sold cheaper but with more volume could lead to enterprises looking to change their avocado type.

# %% [markdown]
# <h3>5.2 Multivariate Analysis</h3>

# %%
#Scatter plots showing correlation between price and volume by type

# Create a figure with 2 subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Scatter plot of Average Price vs Total Volume
sns.scatterplot(data=locations_df, x='TotalVolume', y='AveragePrice', hue='type', ax=ax1)
ax1.set_title('Scatterplot showing Average Price vs Total Volume by Avocado Type')
ax1.set_xlabel('Total Volume')
ax1.set_ylabel('Average Price')

# Calculate the correlation coefficient between AveragePrice and TotalVolume
correlation = locations_df['AveragePrice'].corr(locations_df['TotalVolume'])

# Create the scatterplot with a line of best fit
sns.regplot(
    data=locations_df,
    x="TotalVolume",
    y="AveragePrice",
    scatter_kws={'alpha': 0.6},  # Set transparency for scatter points
    line_kws={'color': 'red'},   # Set color for line of best fit
)

# Set plot title with correlation coefficient
plt.title(f"AveragePrice vs. TotalVolume (Correlation: {correlation:.2f})")
plt.xlabel("Total Volume")
plt.ylabel("Average Price")
# Adjust horizontal spacing between plots
fig.subplots_adjust(wspace=0.5)

plt.show()

# %% [markdown]
# The first graph shows that organic avocados sell much less in volume but vary greatly in price and can be priced much higher. Conventional avocado sales vary more in terms of volume.
#
# The second graph indicates a weak to moderate negative correlation between volume sold and average price. As the total volume increases, the average price decreases. This supports the general notion that buying in bulk tends to be cheaper from a  consumer's perspective.

# %%
# Convert 'Date' columns in both dataframes to datetime format
df['Date'] = pd.to_datetime(df['Date'])
locations_df['Date'] = pd.to_datetime(locations_df['Date'])

# Create a plot to show volume over time by PLU code, without the confidence interval
plt.figure(figsize=(12, 6))

# Plot TotalVolume for each PLU code over time (no confidence interval)
sns.lineplot(
    data=df,
    x='Date',
    y='plu4046',
    label='PLU 4046',
    color='blue',
    ci=None
)
sns.lineplot(
    data=locations_df,
    x='Date',
    y='plu4225',
    label='PLU 4225',
    color='green',
    ci=None
)
sns.lineplot(
    data=locations_df,
    x='Date',
    y='plu4770',
    label='PLU 4770',
    color='orange',
    ci=None
)

# Set plot labels and title
plt.title("Total Volume over Time by PLU Code")
plt.xlabel("Date")
plt.ylabel("Total Volume")
plt.legend(title="PLU Code")

# Display the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Total Volume over Time by PLU Code distinguishes between the different avocado types selling over time. PLU 4770 sells the least in terms of volume but also has much less variability. This could be attributed to lower supply and higher price. The volume and variability increase slightly for PLU 4225 and significantly for PLU 4046. There are dips in the patterns that occur yearly, which can be attributed to seasonal variation.

# %%
# Define the bag size columns
bag_columns = ['TotalBags', 'SmallBags', 'LargeBags', 'XLargeBags']

# Create a figure with subplots for each bag size
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle("TotalVolume vs. Bag Sizes with Correlation Coefficients and Lines of Best Fit", fontsize=16)

# Loop through each bag size column and create a scatterplot with a line of best fit
for ax, bag_column in zip(axes.flatten(), bag_columns):
    # Calculate the correlation coefficient
    correlation = df['TotalVolume'].corr(df[bag_column])
    
    # Plot the scatterplot with a line of best fit
    sns.regplot(
        data=locations_df,
        x=bag_column,
        y="TotalVolume",
        ax=ax,
        scatter_kws={'alpha': 0.6},  # Set transparency for scatter points
        line_kws={'color': 'red'},   # Color for the line of best fit
        ci=None                      # Remove confidence interval for a cleaner plot
    )
    
    # Set title with the correlation coefficient
    ax.set_title(f"TotalVolume vs. {bag_column} (Corr: {correlation:.2f})")
    ax.set_xlabel(bag_column)
    ax.set_ylabel("TotalVolume")

plt.tight_layout()
plt.show()

# %% [markdown]
# All bag sizes generally increase with total volume sold. However, the correlation coefficient is larger as bag size decreases. This indicates that more avocados sell in total when packaged smaller. This is an indication of consumer purchasing patterns, indicating that more consumers tend to buy smaller batches of avocados, allowing for a larger sales in terms of total volume.

# %% [markdown]
# ### 6. Conclusion and Insights

# %% [markdown]
# - Price-Volume Dynamics: While avocado prices fluctuate, there’s little direct correlation between price and sales volume. Despite price volatility, the overall demand for avocados remains strong, with consistent growth in sales volume, suggesting increasing popularity and accessibility over time.
#
# - Price Clusters: The price distribution for both conventional and organic avocados shows two distinct peaks, with the leftmost peak representing the mode price for conventional avocados and the other peak for organic avocados. Conventional avocado prices are more clustered around the mode, suggesting greater price stability, whereas organic avocados exhibit more price variability. Both distributions are slightly positively skewed, indicating that while prices can sometimes be higher, most prices are concentrated in the lower range.
#
# - Seasonality in Price and Volume: The shape of the price and volume curves clearly indicates seasonality in avocado pricing. In the summer months (in the US), prices tend to rise while volume decreases. This pattern suggests that supply and demand dynamics are at play, where lower availability in summer leads to higher prices, and as prices increase, volume tends to decrease due to consumer price sensitivity.
#
# - Regional Trends: Although prices are relatively consistent across regions, sales volume varies significantly, indicating regional differences in demand and consumer preferences. This offers opportunities for tailored marketing and distribution strategies.
#
# - Avocado Type: Conventional avocados dominate the market, both in volume and affordability, while organic options, though pricier, appeal to a niche market. Enterprises could consider adjusting product offerings based on these patterns to optimize sales.
#
# - Consumer Behavior: Smaller bag sizes correlate with higher total sales volume, suggesting that consumers prefer purchasing in smaller quantities. Retailers and producers could capitalize on this trend by emphasizing smaller packaging to boost overall sales.
#
# - Seasonal and PLU Insights: Seasonal variations and specific PLU codes (especially 4046) indicate clear demand patterns. Understanding these patterns helps optimize inventory management and pricing strategies, particularly around peak seasons.
#
# - Price Clustering and Box Plots: The box plots confirm that conventional and organic avocado prices are tightly clustered, with the middle 50% of the data (interquartile range) being narrower for conventional avocados. This further supports the idea that conventional prices are more stable, whereas organic prices show more variability.

# %% [markdown]
# These insights provide a comprehensive overview of market trends, emphasizing seasonality, consumer preferences, and the importance of pricing strategies to optimize sales and respond to demand fluctuations throughout the year.
